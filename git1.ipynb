# %%
import pandas as pd

profile = ['2026-03-25', '조혜림', '2004-05-13', 'ISTP']
profile = pd.Series(profile)

# %%
print(profile)
# Out:
# 0    2026-03-25
# 1           조혜림
# 2    2004-05-13
# 3          ISTP
# dtype: object
