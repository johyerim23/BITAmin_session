# %%
import pandas as pandas

profile = ['2026-03-25', '조혜림', '2004-05-13', 'ISTP']
profile = pd.Series(profile)
# Out:
# 'Python 3.12.12'(으)로 셀을 실행하려면 ipykernel 패키지가 필요합니다.
#
# 필요한 패키지를 사용하여 <a href='command:jupyter.createPythonEnvAndSelectController'>Python 환경 만들기</a>
#
# 또는 다음 명령을 사용하여 'ipykernel'을(를) 설치합니다. 'c:/Users/johye/AppData/Roaming/uv/python/cpython-3.12.12-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
profile
# Out:
# 'Python 3.12.12'(으)로 셀을 실행하려면 ipykernel 패키지가 필요합니다.
#
# 필요한 패키지를 사용하여 <a href='command:jupyter.createPythonEnvAndSelectController'>Python 환경 만들기</a>
#
# 또는 다음 명령을 사용하여 'ipykernel'을(를) 설치합니다. 'c:/Users/johye/AppData/Roaming/uv/python/cpython-3.12.12-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'
